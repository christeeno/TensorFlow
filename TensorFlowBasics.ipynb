# %% [markdown]
# <a href="https://colab.research.google.com/github/christeeno/TensorFlow/blob/main/TensorFlowBasics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np

# %%
xs = np.array([-1.0,  0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

# %%
# Build a simple Sequential model
model = tf.keras.Sequential([

    # Define the input shape
    tf.keras.Input(shape=(1,)),

    # Add a Dense layer
    tf.keras.layers.Dense(units=1)
    ])

# %%
model.compile(optimizer='sgd',loss='mean_squared_error')

# %%
model.fit(xs,ys,epochs=500)
# Out:
# Epoch 1/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - loss: 28.8594
# Epoch 2/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 23.0130
# Epoch 3/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 18.4071
# Epoch 4/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 14.7771
# Epoch 5/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 11.9152
# Epoch 6/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 9.6576
# Epoch 7/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 7.8756
# Epoch 8/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 6.4680
# Epoch 9/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 5.3549
# Epoch 10/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 4.4737
# Epoch 11/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 3.7751
# Epoch 12/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 3.2202
# Epoch 13/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 2.7785
# Epoch 14/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 2.4260
# Epoch 15/500
# ...

# %%
print(f"model predicted: {model.predict(np.array([10.0]), verbose=0).item():.5f}")
# Out:
# model predicted: 18.97921
